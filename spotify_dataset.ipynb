# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\maana\OneDrive\文档\sql\spotify data\artists.csv")

# Save first 5000 rows
df.head(5000).to_csv("artists.csv", index=False)
df.head(5000)
# Out:
#                           id  followers  \
# 0     0DheY5irMjBUeLybbCUEZ2        0.0
# 1     0DlhY15l3wsrnlfGio2bjU        5.0
# 2     0DmRESX2JknGPQyO15yxg7        0.0
# 3     0DmhnbHjm1qw6NCYPeZNgJ        0.0
# 4     0Dn11fWM7vHQ3rinvWEl4E        2.0
# ...                      ...        ...
# 4995  7Jp5Nw7cNZTkwFgJX06Cqk   361983.0
# 4996  0kj68SnX4WCXwveyBbRX8p    29900.0
# 4997  03lJxNYml1ArLjcZLxfIvz  2080285.0
# 4998  3DAlQBPv5zWasPxV5Tr8ok    14159.0
# 4999  2Ip2jiEjsSe8pmRBzwTv5N    47316.0
#
#                                                  genres  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 4995                        ['rap df', 'sertanejo pop']
# ...

# %%
db = pd.read_csv(r"C:\Users\maana\OneDrive\文档\sql\spotify data\SpotifyFeatures.csv")

# Save first 5000 rows
db.head(5000).to_csv("spotify_features.csv", index=False)
db.head(5000)
# Out:
#             genre              artist_name                        track_name  \
# 0           Movie           Henri Salvador       C'est beau de faire un Show
# 1           Movie        Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2           Movie          Joseph Williams    Don't Let Me Be Lonely Tonight
# 3           Movie           Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4           Movie             Fabien Nataf                         Ouverture
# ...           ...                      ...                               ...
# 4995  Alternative                      UMI                       High School
# 4996  Alternative       for KING & COUNTRY                         Shoulders
# 4997  Alternative  Queens of the Stone Age                Feet Don't Fail Me
# 4998  Alternative               Atmosphere                      The Best Day
# 4999  Alternative   Florence + The Machine                           Big God
#
# ...

# %%
dt = pd.read_csv(r"C:\Users\maana\OneDrive\文档\sql\spotify data\tracks.csv")

# Save first 5000 rows
dt.head(5000).to_csv("tracks.csv", index=False)
dt.head(5000)
# Out:
#                           id  \
# 0     35iwgR4jXetI318WEWsa1Q
# 1     021ht4sdgPcrDgSk7JTbKY
# 2     07A5yehtSnoedViJAZkNnc
# 3     08FmqUhxtyLTn6pAh6bk45
# 4     08y9GfoqCWfOGsKdwojr5e
# ...                      ...
# 4995  1dWZCMwYq2c5WIh1ti5mgz
# 4996  1dxKJpiZmdvmIPzzcRLk24
# 4997  1eHJ0HNzSVAC5xvC5fK2A2
# 4998  1eIrN38INCVanDji2pnsEj
# 4999  1edSnJ9AVeZLq289IDBSFa
#
#                                                    name  popularity  \
# 0                                                 Carve           6
# 1                   Capítulo 2.16 - Banquero Anarquista           0
# 2                    Vivo para Quererte - Remasterizado           0
# 3                         El Prisionero - Remasterizado           0
# 4                                   Lady of the Evening           0
# ...                                                 ...         ...
# 4995                No Quiero Verla Más - Remasterizado           0
# ...
